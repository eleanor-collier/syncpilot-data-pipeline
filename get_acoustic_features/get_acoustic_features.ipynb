# %% [markdown]
# # Get acoustic features of disclosures via Praat

# %%
import glob
import math
import os
import re
import subprocess
import numpy as np
import pandas as pd
import parselmouth 

from parselmouth.praat import call

# Set working directory
os.chdir('/Users/Eleanor2/Library/CloudStorage/GoogleDrive-airfire246@gmail.com/My Drive/UCR/UCR SNL/Research Projects/SyncDisclosures/Pilot/Analysis/')

# %%
# Set parameters
f0min = 75 # 75 for males, 100 for females
f0max = 500 # 300 for males, 500 for females
time_step = 1.0 # 1 second

# %% [markdown]
# Maybe parallelize this in the future: https://medium.com/@mjschillawski/quick-and-easy-parallelization-in-python-32cb9027e490

# %%
# Loop through participant folders & self-disclosure recordings on Google Drive
all_acoustics = []
for subdir, dirs, files in os.walk('Data/recordings'):
    for file in files: 
        
        # Only include real participants' data and self (not partner's) disclosures
        if '/P' in os.path.join(subdir, file) and 'self' in os.path.join(subdir, file):
            
            # Convert m4a file to wav
            file_path = os.path.join(subdir, file)
            wav_file_path = file_path.replace(".m4a",".wav")
            subprocess.call(['ffmpeg', '-i', file_path, wav_file_path])
            
            # Import audio recording
            sound = parselmouth.Sound(wav_file_path)
            
            # Delete wav file to save space
            os.remove(wav_file_path)
            
            # Get participant ID
            regex = re.compile('/')
            ID = regex.split(wav_file_path)[2].replace("P","")
            
            # Get disclosure name
            regex = re.compile('_')
            disclosure = regex.split(wav_file_path)[2].replace(".wav","")
            
            print('Processing P' + ID + ', disclosure ' + disclosure)
            
            # Get audio start time and end time
            tmin = math.floor(call(sound, "Get start time"))
            tmax = math.ceil(call(sound, "Get end time"))
            
            # Get timestamps
            times = list(range(tmin, tmax))
            
            # Compute pitch
            pitch = sound.to_pitch(time_step, f0min, f0max)
            pitch_values = pitch.selected_array['frequency']
            if len(pitch_values) < tmax:
                pitch_values = np.append( # if missing time points, pad with NaN
                    pitch_values, np.zeros(tmax - len(pitch_values)) + np.nan
                )
            
            # Compute intensity
            intensity = sound.to_intensity(f0min, time_step)
            intensity_values = intensity.values[0]
            if len(intensity_values) < tmax:
                intensity_values = np.append( # if missing time points, pad with NaN
                    intensity_values, np.zeros(tmax - len(intensity_values)) + np.nan
                )
                
            # Compute HF500
            hf500 = []
            for time in range(tmin, tmax):
                sound_part = call(sound, "Extract part", time - time_step, time, "rectangular", 1, "yes")
                spectrum = call(sound_part, "To Spectrum", "yes")
                top = call(spectrum, "Get highest frequency")
                lo = call(spectrum, "Get band energy", 0, 500)
                hi = call(spectrum, "Get band energy", 500, top)
                # Convert sound pressure level from pascals to DB; set to nan if zero division occurs
                try:
                    hf500_at_time = 10 * math.log10(hi / lo)
                except ZeroDivisionError:
                    hf500_at_time = np.nan
                hf500.append(hf500_at_time)
            
            # Compute jitter
            jitter = []
            for time in range(tmin, tmax):
                sound_part = call(sound, "Extract part", time - time_step, time, "rectangular", 1, "yes")
                pointProcess = call(sound_part, "To PointProcess (periodic, cc)", f0min, f0max)
                jitter_at_time = call(pointProcess, "Get jitter (local)", 0, 0, 0.0001, 0.02, 1.3)
                jitter.append(jitter_at_time)
                
            # Compute shimmer
            shimmer = []
            for time in range(tmin, tmax):
                sound_part = call(sound, "Extract part", time - time_step, time, "rectangular", 1, "yes")
                pointProcess = call(sound_part, "To PointProcess (periodic, cc)", f0min, f0max)
                shimmer_at_time = call([sound, pointProcess], "Get shimmer (local)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
                shimmer.append(shimmer_at_time)
                
            # Compute formants
            f1_list = []
            f2_list = []
            f3_list = []
            f4_list = []
            formants = call(sound, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)
            for time in range(tmin, tmax):
                f1 = call(formants, "Get value at time", 1, time, 'Hertz', 'Linear')
                f2 = call(formants, "Get value at time", 2, time, 'Hertz', 'Linear')
                f3 = call(formants, "Get value at time", 3, time, 'Hertz', 'Linear')
                f4 = call(formants, "Get value at time", 4, time, 'Hertz', 'Linear')
                f1_list.append(f1)
                f2_list.append(f2)
                f3_list.append(f3)
                f4_list.append(f4)
             
            # Create data frame of accoustic features & append to master list
            accoustics_df = pd.DataFrame({
                'ID': ID,
                'disclosure': disclosure,
                'time': times, 
                'pitch': pitch_values, 
                'intensity': intensity_values,
                'hf500': hf500,
                'jitter': jitter,
                'shimmer': shimmer,
                'f1': f1_list,
                'f2': f2_list,
                'f3': f3_list,
                'f4': f4_list
                })
            all_acoustics.append(accoustics_df)
# Out:
# Processing P136, disclosure pos2
# Processing P136, disclosure pos1
# Processing P136, disclosure neu1
# Processing P136, disclosure neu2
# Processing P136, disclosure neg1
# Processing P136, disclosure neg2
# Processing P131, disclosure pos2
# Processing P131, disclosure pos1
# Processing P131, disclosure neu1
# Processing P131, disclosure neu2
# Processing P131, disclosure neg1
# Processing P131, disclosure neg2
# Processing P138, disclosure pos2
# Processing P138, disclosure pos1
# Processing P138, disclosure neu1
# Processing P138, disclosure neu2
# Processing P138, disclosure neg1
# Processing P138, disclosure neg2
# Processing P107, disclosure pos2
# Processing P107, disclosure pos1
# Processing P107, disclosure neu1
# Processing P107, disclosure neu2
# Processing P107, disclosure neg1
# Processing P107, disclosure neg2
# Processing P100, disclosure pos2
# Processing P100, disclosure pos1
# Processing P100, disclosure neu1
# Processing P100, disclosure neu2
# Processing P100, disclosure neg1
# Processing P100, disclosure neg2
# Processing P154, disclosure pos2
# Processing P154, disclosure pos1
# Processing P154, disclosure neu1
# Processing P154, disclosure neu2
# Processing P154, disclosure neg1
# Processing P154, disclosure neg2
# Processing P153, disclosure pos2
# Processing P153, disclosure pos1
# Processing P153, disclosure neu1
# Processing P153, disclosure neu2
# Processing P153, disclosure neg1
# Processing P153, disclosure neg2
# Processing P165, disclosure pos2
# Processing P165, disclosure pos1
# Processing P165, disclosure neu1
# Processing P165, disclosure neu2
# Processing P165, disclosure neg1
# Processing P165, disclosure neg2
# Processing P101, disclosure pos2
# Processing P101, disclosure pos1
# Processing P101, disclosure neu1
# Processing P101, disclosure neu2
# Processing P101, disclosure neg1
# Processing P101, disclosure neg2
# Processing P139, disclosure pos2
# Processing P139, disclosure pos1
# Processing P139, disclosure neu1
# Processing P139, disclosure neu2
# Processing P139, disclosure neg1
# Processing P139, disclosure neg2
# Processing P106, disclosure pos2
# Processing P106, disclosure pos1
# Processing P106, disclosure neu1
# Processing P106, disclosure neu2
# Processing P106, disclosure neg1
# Processing P106, disclosure neg2
# Processing P130, disclosure pos2
# Processing P130, disclosure pos1
# Processing P130, disclosure neu1
# Processing P130, disclosure neu2
# Processing P130, disclosure neg1
# Processing P130, disclosure neg2
# Processing P108, disclosure pos2
# Processing P108, disclosure pos1
# Processing P108, disclosure neu1
# Processing P108, disclosure neu2
# Processing P108, disclosure neg1
# Processing P108, disclosure neg2
# Processing P137, disclosure pos2
# Processing P137, disclosure pos1
# Processing P137, disclosure neu1
# Processing P137, disclosure neu2
# Processing P137, disclosure neg1
# Processing P137, disclosure neg2
# Processing P163, disclosure pos2
# Processing P163, disclosure pos1
# Processing P163, disclosure neu1
# Processing P163, disclosure neu2
# Processing P163, disclosure neg1
# Processing P163, disclosure neg2
# Processing P164, disclosure pos2
# Processing P164, disclosure pos1
# Processing P164, disclosure neu1
# Processing P164, disclosure neu2
# Processing P164, disclosure neg1
# Processing P164, disclosure neg2
# Processing P152, disclosure pos2
# Processing P152, disclosure pos1
# Processing P152, disclosure neu1
# Processing P152, disclosure neu2
# Processing P152, disclosure neg1
# Processing P152, disclosure neg2
# Processing P155, disclosure pos2
# Processing P155, disclosure pos1
# Processing P155, disclosure neu1
# Processing P155, disclosure neu2
# Processing P155, disclosure neg1
# Processing P155, disclosure neg2
# Processing P19, disclosure pos2
# Processing P19, disclosure pos1
# Processing P19, disclosure neu1
# Processing P19, disclosure neu2
# Processing P19, disclosure neg1
# Processing P19, disclosure neg2
# Processing P21, disclosure pos2
# Processing P21, disclosure pos1
# Processing P21, disclosure neu1
# Processing P21, disclosure neu2
# Processing P21, disclosure neg1
# Processing P21, disclosure neg2
# Processing P28, disclosure pos2
# Processing P28, disclosure pos1
# Processing P28, disclosure neu1
# Processing P28, disclosure neu2
# Processing P28, disclosure neg1
# Processing P28, disclosure neg2
# Processing P17, disclosure pos2
# Processing P17, disclosure pos1
# Processing P17, disclosure neu1
# Processing P17, disclosure neu2
# Processing P17, disclosure neg1
# Processing P17, disclosure neg2
# Processing P10, disclosure pos2
# Processing P10, disclosure pos1
# Processing P10, disclosure neu1
# Processing P10, disclosure neu2
# Processing P10, disclosure neg1
# Processing P10, disclosure neg2
# Processing P44, disclosure pos2
# Processing P44, disclosure pos1
# Processing P44, disclosure neu1
# Processing P44, disclosure neu2
# Processing P44, disclosure neg1
# Processing P44, disclosure neg2
# Processing P43, disclosure pos2
# Processing P43, disclosure pos1
# Processing P43, disclosure neu1
# Processing P43, disclosure neu2
# Processing P43, disclosure neg1
# Processing P43, disclosure neg2
# Processing P88, disclosure pos2
# Processing P88, disclosure pos1
# Processing P88, disclosure neu1
# Processing P88, disclosure neu2
# Processing P88, disclosure neg1
# Processing P88, disclosure neg2
# Processing P75, disclosure pos2
# Processing P75, disclosure pos1
# Processing P75, disclosure neu1
# Processing P75, disclosure neu2
# Processing P75, disclosure neg1
# Processing P75, disclosure neg2
# Processing P81, disclosure pos2
# Processing P81, disclosure pos1
# Processing P81, disclosure neu1
# Processing P81, disclosure neu2
# Processing P81, disclosure neg1
# Processing P81, disclosure neg2
# Processing P72, disclosure pos2
# Processing P72, disclosure pos1
# Processing P72, disclosure neu1
# Processing P72, disclosure neu2
# Processing P72, disclosure neg1
# Processing P72, disclosure neg2
# Processing P11, disclosure pos2
# Processing P11, disclosure pos1
# Processing P11, disclosure neu1
# Processing P11, disclosure neu2
# Processing P11, disclosure neg1
# Processing P11, disclosure neg2
# Processing P29, disclosure pos2
# Processing P29, disclosure pos1
# Processing P29, disclosure neu1
# Processing P29, disclosure neu2
# Processing P29, disclosure neg1
# Processing P29, disclosure neg2
# Processing P16, disclosure pos2
# Processing P16, disclosure pos1
# Processing P16, disclosure neu1
# Processing P16, disclosure neu2
# Processing P16, disclosure neg1
# Processing P16, disclosure neg2
# Processing P20, disclosure pos2
# Processing P20, disclosure pos1
# Processing P20, disclosure neu1
# Processing P20, disclosure neu2
# Processing P20, disclosure neg1
# Processing P20, disclosure neg2
# Processing P18, disclosure pos2
# Processing P18, disclosure pos1
# Processing P18, disclosure neu1
# Processing P18, disclosure neu2
# Processing P18, disclosure neg1
# Processing P18, disclosure neg2
# Processing P27, disclosure pos2
# Processing P27, disclosure pos1
# Processing P27, disclosure neu1
# Processing P27, disclosure neu2
# Processing P27, disclosure neg1
# Processing P27, disclosure neg2
# Processing P73, disclosure pos2
# Processing P73, disclosure pos1
# Processing P73, disclosure neu1
# Processing P73, disclosure neu2
# Processing P73, disclosure neg1
# Processing P73, disclosure neg2
# Processing P87, disclosure pos2
# Processing P87, disclosure pos1
# Processing P87, disclosure neu1
# Processing P87, disclosure neu2
# Processing P87, disclosure neg1
# Processing P87, disclosure neg2
# Processing P80, disclosure pos2
# Processing P80, disclosure pos1
# Processing P80, disclosure neu1
# Processing P80, disclosure neu2
# Processing P80, disclosure neg1
# Processing P80, disclosure neg2
# Processing P74, disclosure pos2
# Processing P74, disclosure pos1
# Processing P74, disclosure neu1
# Processing P74, disclosure neu2
# Processing P74, disclosure neg1
# Processing P74, disclosure neg2
# Processing P42, disclosure pos2
# Processing P42, disclosure pos1
# Processing P42, disclosure neu1
# Processing P42, disclosure neu2
# Processing P42, disclosure neg1
# Processing P42, disclosure neg2
# Processing P89, disclosure pos2
# Processing P89, disclosure pos1
# Processing P89, disclosure neu1
# Processing P89, disclosure neu2
# Processing P89, disclosure neg1
# Processing P89, disclosure neg2
# Processing P58, disclosure pos2
# Processing P58, disclosure pos1
# Processing P58, disclosure neu1
# Processing P58, disclosure neu2
# Processing P58, disclosure neg1
# Processing P58, disclosure neg2
# Processing P67, disclosure pos2
# Processing P67, disclosure pos1
# Processing P67, disclosure neu1
# Processing P67, disclosure neu2
# Processing P67, disclosure neg1
# Processing P67, disclosure neg2
# Processing P93, disclosure pos2
# Processing P93, disclosure pos1
# Processing P93, disclosure neu1
# Processing P93, disclosure neu2
# Processing P93, disclosure neg1
# Processing P93, disclosure neg2
# Processing P94, disclosure pos2
# Processing P94, disclosure pos1
# Processing P94, disclosure neu1
# Processing P94, disclosure neu2
# Processing P94, disclosure neg1
# Processing P94, disclosure neg2
# Processing P69, disclosure pos2
# Processing P69, disclosure pos1
# Processing P69, disclosure neu1
# Processing P69, disclosure neu2
# Processing P69, disclosure neg1
# Processing P69, disclosure neg2
# Processing P56, disclosure pos2
# Processing P56, disclosure pos1
# Processing P56, disclosure neu1
# Processing P56, disclosure neu2
# Processing P56, disclosure neg1
# Processing P56, disclosure neg2
# Processing P51, disclosure pos2
# Processing P51, disclosure pos1
# Processing P51, disclosure neu1
# Processing P51, disclosure neu2
# Processing P51, disclosure neg1
# Processing P51, disclosure neg2
# Processing P05, disclosure pos2
# Processing P05, disclosure pos1
# Processing P05, disclosure neu1
# Processing P05, disclosure neu2
# Processing P05, disclosure neg1
# Processing P05, disclosure neg2
# Processing P02, disclosure pos2
# Processing P02, disclosure pos1
# Processing P02, disclosure neu1
# Processing P02, disclosure neu2
# Processing P02, disclosure neg1
# Processing P02, disclosure neg2
# Processing P34, disclosure pos4
# Processing P34, disclosure pos5
# Processing P34, disclosure pos6
# Processing P34, disclosure pos3
# Processing P34, disclosure neu1
# Processing P34, disclosure neu2
# Processing P33, disclosure pos2
# Processing P33, disclosure pos1
# Processing P33, disclosure neu1
# Processing P33, disclosure neu2
# Processing P33, disclosure neg1
# Processing P33, disclosure neg2
# Processing P50, disclosure pos2
# Processing P50, disclosure pos1
# Processing P50, disclosure neu1
# Processing P50, disclosure neu2
# Processing P50, disclosure neg1
# Processing P50, disclosure neg2
# Processing P68, disclosure pos2
# Processing P68, disclosure pos1
# Processing P68, disclosure neu1
# Processing P68, disclosure neu2
# Processing P68, disclosure neg1
# Processing P68, disclosure neg2
# Processing P57, disclosure pos2
# Processing P57, disclosure pos1
# Processing P57, disclosure neu1
# Processing P57, disclosure neu2
# Processing P57, disclosure neg1
# Processing P57, disclosure neg2
# Processing P95, disclosure pos2
# Processing P95, disclosure pos1
# Processing P95, disclosure neu1
# Processing P95, disclosure neu2
# Processing P95, disclosure neg1
# Processing P95, disclosure neg2
# Processing P66, disclosure pos2
# Processing P66, disclosure pos1
# Processing P66, disclosure neu1
# Processing P66, disclosure neu2
# Processing P66, disclosure neg1
# Processing P66, disclosure neg2
# Processing P32, disclosure pos2
# Processing P32, disclosure pos1
# Processing P32, disclosure neu1
# Processing P32, disclosure neu2
# Processing P32, disclosure neg1
# Processing P32, disclosure neg2
# Processing P35, disclosure pos2
# Processing P35, disclosure pos1
# Processing P35, disclosure neu1
# Processing P35, disclosure neu2
# Processing P35, disclosure neg1
# Processing P35, disclosure neg2
# Processing P03, disclosure pos2
# Processing P03, disclosure pos1
# Processing P03, disclosure neu1
# Processing P03, disclosure neu2
# Processing P03, disclosure neg1
# Processing P03, disclosure neg2
# Processing P04, disclosure pos2
# Processing P04, disclosure pos1
# Processing P04, disclosure neu1
# Processing P04, disclosure neu2
# Processing P04, disclosure neg1
# Processing P04, disclosure neg2
# Processing P148, disclosure pos2
# Processing P148, disclosure pos1
# Processing P148, disclosure neu1
# Processing P148, disclosure neu2
# Processing P148, disclosure neg1
# Processing P148, disclosure neg2
# Processing P177, disclosure pos2
# Processing P177, disclosure pos1
# Processing P177, disclosure neu1
# Processing P177, disclosure neu2
# Processing P177, disclosure neg1
# Processing P177, disclosure neg2
# Processing P141, disclosure pos2
# Processing P141, disclosure pos1
# Processing P141, disclosure neu1
# Processing P141, disclosure neu2
# Processing P141, disclosure neg1
# Processing P141, disclosure neg2
# Processing P112, disclosure pos2
# Processing P112, disclosure pos1
# Processing P112, disclosure neu1
# Processing P112, disclosure neu2
# Processing P112, disclosure neg1
# Processing P112, disclosure neg2
# Processing P124, disclosure pos2
# Processing P124, disclosure pos1
# Processing P124, disclosure neu1
# Processing P124, disclosure neu2
# Processing P124, disclosure neg1
# Processing P124, disclosure neg2
# Processing P123, disclosure pos2
# Processing P123, disclosure pos1
# Processing P123, disclosure neu1
# Processing P123, disclosure neu2
# Processing P123, disclosure neg1
# Processing P123, disclosure neg2
# Processing P140, disclosure pos2
# Processing P140, disclosure pos1
# Processing P140, disclosure neu1
# Processing P140, disclosure neu2
# Processing P140, disclosure neg1
# Processing P140, disclosure neg2
# Processing P178, disclosure pos2
# Processing P178, disclosure pos1
# Processing P178, disclosure neu1
# Processing P178, disclosure neu2
# Processing P178, disclosure neg1
# Processing P178, disclosure neg2
# Processing P147, disclosure pos2
# Processing P147, disclosure pos1
# Processing P147, disclosure neu1
# Processing P147, disclosure neu2
# Processing P147, disclosure neg1
# Processing P147, disclosure neg2
# Processing P171, disclosure pos2
# Processing P171, disclosure pos1
# Processing P171, disclosure neu1
# Processing P171, disclosure neu2
# Processing P171, disclosure neg1
# Processing P171, disclosure neg2
# Processing P149, disclosure pos2
# Processing P149, disclosure pos1
# Processing P149, disclosure neu1
# Processing P149, disclosure neu2
# Processing P149, disclosure neg1
# Processing P149, disclosure neg2
# Processing P176, disclosure pos2
# Processing P176, disclosure pos1
# Processing P176, disclosure neu1
# Processing P176, disclosure neu2
# Processing P176, disclosure neg1
# Processing P176, disclosure neg2
# Processing P182, disclosure pos2
# Processing P182, disclosure pos1
# Processing P182, disclosure neu1
# Processing P182, disclosure neu2
# Processing P182, disclosure neg1
# Processing P182, disclosure neg2
# Processing P122, disclosure pos2
# Processing P122, disclosure pos1
# Processing P122, disclosure neu1
# Processing P122, disclosure neu2
# Processing P122, disclosure neg1
# Processing P122, disclosure neg2
# Processing P113, disclosure pos2
# Processing P113, disclosure pos1
# Processing P113, disclosure neu1
# Processing P113, disclosure neu2
# Processing P113, disclosure neg1
# Processing P113, disclosure neg2
# Processing P114, disclosure pos2
# Processing P114, disclosure pos1
# Processing P114, disclosure neu1
# Processing P114, disclosure neu2
# Processing P114, disclosure neg1
# Processing P114, disclosure neg2
# Processing P150, disclosure pos2
# Processing P150, disclosure pos1
# Processing P150, disclosure neu1
# Processing P150, disclosure neu2
# Processing P150, disclosure neg1
# Processing P150, disclosure neg2
# Processing P157, disclosure pos2
# Processing P157, disclosure pos1
# Processing P157, disclosure neu1
# Processing P157, disclosure neu2
# Processing P157, disclosure neg1
# Processing P157, disclosure neg2
# Processing P168, disclosure pos2
# Processing P168, disclosure pos1
# Processing P168, disclosure neu1
# Processing P168, disclosure neu2
# Processing P168, disclosure neg1
# Processing P168, disclosure neg2
# Processing P166, disclosure pos2
# Processing P166, disclosure pos1
# Processing P166, disclosure neu1
# Processing P166, disclosure neu2
# Processing P166, disclosure neg1
# Processing P166, disclosure neg2
# Processing P159, disclosure pos2
# Processing P159, disclosure pos1
# Processing P159, disclosure neu1
# Processing P159, disclosure neu2
# Processing P159, disclosure neg1
# Processing P159, disclosure neg2
# Processing P132, disclosure pos2
# Processing P132, disclosure pos1
# Processing P132, disclosure neu1
# Processing P132, disclosure neu2
# Processing P132, disclosure neg1
# Processing P132, disclosure neg2
# Processing P135, disclosure pos2
# Processing P135, disclosure pos1
# Processing P135, disclosure neu1
# Processing P135, disclosure neu2
# Processing P135, disclosure neg1
# Processing P135, disclosure neg2
# Processing P167, disclosure pos2
# Processing P167, disclosure pos1
# Processing P167, disclosure neu1
# Processing P167, disclosure neu2
# Processing P167, disclosure neg1
# Processing P167, disclosure neg2
# Processing P158, disclosure pos2
# Processing P158, disclosure pos1
# Processing P158, disclosure neu1
# Processing P158, disclosure neu2
# Processing P158, disclosure neg1
# Processing P158, disclosure neg2
# Processing P160, disclosure pos2
# Processing P160, disclosure pos1
# Processing P160, disclosure neu1
# Processing P160, disclosure neu2
# Processing P160, disclosure neg1
# Processing P160, disclosure neg2
# Processing P156, disclosure pos2
# Processing P156, disclosure pos1
# Processing P156, disclosure neu1
# Processing P156, disclosure neu2
# Processing P156, disclosure neg1
# Processing P156, disclosure neg2
# Processing P151, disclosure pos2
# Processing P151, disclosure pos1
# Processing P151, disclosure neu1
# Processing P151, disclosure neu2
# Processing P151, disclosure neg1
# Processing P151, disclosure neg2
# Processing P105, disclosure pos2
# Processing P105, disclosure pos1
# Processing P105, disclosure neu1
# Processing P105, disclosure neu2
# Processing P105, disclosure neg1
# Processing P105, disclosure neg2
# Processing P102, disclosure pos2
# Processing P102, disclosure pos1
# Processing P102, disclosure neu1
# Processing P102, disclosure neu2
# Processing P102, disclosure neg1
# Processing P102, disclosure neg2
# Processing P134, disclosure pos2
# Processing P134, disclosure pos1
# Processing P134, disclosure neu1
# Processing P134, disclosure neu2
# Processing P134, disclosure neg1
# Processing P134, disclosure neg2
# Processing P133, disclosure pos2
# Processing P133, disclosure pos1
# Processing P133, disclosure neu1
# Processing P133, disclosure neu2
# Processing P133, disclosure neg1
# Processing P133, disclosure neg2
# Processing P40, disclosure pos2
# Processing P40, disclosure pos1
# Processing P40, disclosure neu1
# Processing P40, disclosure neu2
# Processing P40, disclosure neg1
# Processing P40, disclosure neg2
# Processing P47, disclosure pos2
# Processing P47, disclosure pos1
# Processing P47, disclosure neu1
# Processing P47, disclosure neu2
# Processing P47, disclosure neg1
# Processing P47, disclosure neg2
# Processing P78, disclosure pos2
# Processing P78, disclosure pos1
# Processing P78, disclosure neu1
# Processing P78, disclosure neu2
# Processing P78, disclosure neg1
# Processing P78, disclosure neg2
# Processing P71, disclosure pos2
# Processing P71, disclosure pos1
# Processing P71, disclosure neu1
# Processing P71, disclosure neu2
# Processing P71, disclosure neg1
# Processing P71, disclosure neg2
# Processing P76, disclosure pos2
# Processing P76, disclosure pos1
# Processing P76, disclosure neu1
# Processing P76, disclosure neu2
# Processing P76, disclosure neg1
# Processing P76, disclosure neg2
# Processing P82, disclosure pos2
# Processing P82, disclosure pos1
# Processing P82, disclosure neu1
# Processing P82, disclosure neu2
# Processing P82, disclosure neg1
# Processing P82, disclosure neg2
# Processing P49, disclosure pos2
# Processing P49, disclosure pos1
# Processing P49, disclosure neu1
# Processing P49, disclosure neu2
# Processing P49, disclosure neg1
# Processing P49, disclosure neg2
# Processing P22, disclosure pos2
# Processing P22, disclosure pos1
# Processing P22, disclosure neu1
# Processing P22, disclosure neu2
# Processing P22, disclosure neg1
# Processing P22, disclosure neg2
# Processing P83, disclosure pos2
# Processing P83, disclosure pos1
# Processing P83, disclosure neu1
# Processing P83, disclosure neu2
# Processing P83, disclosure neg1
# Processing P83, disclosure neg2
# Processing P77, disclosure pos2
# Processing P77, disclosure pos1
# Processing P77, disclosure neu1
# Processing P77, disclosure neu2
# Processing P77, disclosure neg1
# Processing P77, disclosure neg2
# Processing P48, disclosure pos2
# Processing P48, disclosure pos1
# Processing P48, disclosure neu1
# Processing P48, disclosure neu2
# Processing P48, disclosure neg1
# Processing P48, disclosure neg2
# Processing P70, disclosure pos2
# Processing P70, disclosure pos1
# Processing P70, disclosure neu1
# Processing P70, disclosure neu2
# Processing P70, disclosure neg1
# Processing P70, disclosure neg2
# Processing P84, disclosure pos2
# Processing P84, disclosure pos1
# Processing P84, disclosure neu1
# Processing P84, disclosure neu2
# Processing P84, disclosure neg1
# Processing P84, disclosure neg2
# Processing P79, disclosure pos2
# Processing P79, disclosure pos1
# Processing P79, disclosure neu1
# Processing P79, disclosure neu2
# Processing P79, disclosure neg1
# Processing P79, disclosure neg2
# Processing P41, disclosure pos2
# Processing P41, disclosure pos1
# Processing P41, disclosure neu1
# Processing P41, disclosure neu2
# Processing P41, disclosure neg1
# Processing P41, disclosure neg2
# Processing P15, disclosure pos2
# Processing P15, disclosure pos1
# Processing P15, disclosure neu1
# Processing P15, disclosure neu2
# Processing P15, disclosure neg1
# Processing P15, disclosure neg2
# Processing P12, disclosure pos2
# Processing P12, disclosure pos1
# Processing P12, disclosure neu1
# Processing P12, disclosure neu2
# Processing P12, disclosure neg1
# Processing P12, disclosure neg2
# Processing P24, disclosure pos2
# Processing P24, disclosure pos1
# Processing P24, disclosure neu1
# Processing P24, disclosure neu2
# Processing P24, disclosure neg1
# Processing P24, disclosure neg2
# Processing P23, disclosure pos2
# Processing P23, disclosure pos1
# Processing P23, disclosure neu1
# Processing P23, disclosure neu2
# Processing P23, disclosure neg1
# Processing P23, disclosure neg2
# Processing P01, disclosure pos2
# Processing P01, disclosure pos1
# Processing P01, disclosure neu1
# Processing P01, disclosure neu2
# Processing P01, disclosure neg1
# Processing P01, disclosure neg2
# Processing P06, disclosure pos2
# Processing P06, disclosure pos1
# Processing P06, disclosure neu1
# Processing P06, disclosure neu2
# Processing P06, disclosure neg1
# Processing P06, disclosure neg2
# Processing P39, disclosure pos2
# Processing P39, disclosure pos1
# Processing P39, disclosure neg1
# Processing P39, disclosure neg2
# Processing P39, disclosure neu1
# Processing P39, disclosure neu2
# Processing P30, disclosure pos2
# Processing P30, disclosure pos1
# Processing P30, disclosure neu1
# Processing P30, disclosure neu2
# Processing P30, disclosure neg1
# Processing P30, disclosure neg2
# Processing P37, disclosure pos2
# Processing P37, disclosure pos1
# Processing P37, disclosure neu1
# Processing P37, disclosure neu2
# Processing P37, disclosure neg1
# Processing P37, disclosure neg2
# Processing P08, disclosure pos2
# Processing P08, disclosure pos1
# Processing P08, disclosure neu1
# Processing P08, disclosure neu2
# Processing P08, disclosure neg1
# Processing P08, disclosure neg2
# Processing P63, disclosure pos2
# Processing P63, disclosure pos1
# Processing P63, disclosure neu1
# Processing P63, disclosure neu2
# Processing P63, disclosure neg1
# Processing P63, disclosure neg2
# Processing P64, disclosure pos2
# Processing P64, disclosure pos1
# Processing P64, disclosure neu1
# Processing P64, disclosure neu2
# Processing P64, disclosure neg1
# Processing P64, disclosure neg2
# Processing P90, disclosure pos2
# Processing P90, disclosure pos1
# Processing P90, disclosure neu1
# Processing P90, disclosure neu2
# Processing P90, disclosure neg1
# Processing P90, disclosure neg2
# Processing P99, disclosure pos2
# Processing P99, disclosure pos1
# Processing P99, disclosure neu1
# Processing P99, disclosure neu2
# Processing P99, disclosure neg1
# Processing P99, disclosure neg2
# Processing P52, disclosure pos2
# Processing P52, disclosure pos1
# Processing P52, disclosure neu1
# Processing P52, disclosure neu2
# Processing P52, disclosure neg1
# Processing P52, disclosure neg2
# Processing P55, disclosure pos2
# Processing P55, disclosure pos1
# Processing P55, disclosure neu1
# Processing P55, disclosure neu2
# Processing P55, disclosure neg1
# Processing P55, disclosure neg2
# Processing P36, disclosure pos2
# Processing P36, disclosure pos1
# Processing P36, disclosure neu1
# Processing P36, disclosure neu2
# Processing P36, disclosure neg1
# Processing P36, disclosure neg2
# Processing P09, disclosure pos2
# Processing P09, disclosure pos1
# Processing P09, disclosure neu1
# Processing P09, disclosure neu2
# Processing P09, disclosure neg1
# Processing P09, disclosure neg2
# Processing P31, disclosure pos2
# Processing P31, disclosure pos1
# Processing P31, disclosure neu1
# Processing P31, disclosure neu2
# Processing P31, disclosure neg1
# Processing P31, disclosure neg2
# Processing P07, disclosure pos2
# Processing P07, disclosure pos1
# Processing P07, disclosure neu1
# Processing P07, disclosure neu2
# Processing P07, disclosure neg1
# Processing P07, disclosure neg2
# Processing P38, disclosure pos2
# Processing P38, disclosure pos1
# Processing P38, disclosure neu1
# Processing P38, disclosure neu2
# Processing P38, disclosure neg1
# Processing P38, disclosure neg2
# Processing P54, disclosure pos2
# Processing P54, disclosure pos1
# Processing P54, disclosure neu1
# Processing P54, disclosure neu2
# Processing P54, disclosure neg1
# Processing P54, disclosure neg2
# Processing P53, disclosure pos2
# Processing P53, disclosure pos1
# Processing P53, disclosure neu1
# Processing P53, disclosure neu2
# Processing P53, disclosure neg1
# Processing P53, disclosure neg2
# Processing P65, disclosure pos2
# Processing P65, disclosure pos1
# Processing P65, disclosure neu1
# Processing P65, disclosure neu2
# Processing P65, disclosure neg1
# Processing P65, disclosure neg2
# Processing P96, disclosure pos2
# Processing P96, disclosure pos1
# Processing P96, disclosure neu1
# Processing P96, disclosure neu2
# Processing P96, disclosure neg1
# Processing P96, disclosure neg2
# Processing P111, disclosure pos2
# Processing P111, disclosure pos1
# Processing P111, disclosure neu1
# Processing P111, disclosure neu2
# Processing P111, disclosure neg1
# Processing P111, disclosure neg2
# Processing P129, disclosure pos2
# Processing P129, disclosure pos1
# Processing P129, disclosure neu1
# Processing P129, disclosure neu2
# Processing P129, disclosure neg1
# Processing P129, disclosure neg2
# Processing P120, disclosure pos2
# Processing P120, disclosure pos1
# Processing P120, disclosure neu1
# Processing P120, disclosure neu2
# Processing P120, disclosure neg1
# Processing P120, disclosure neg2
# Processing P127, disclosure pos2
# Processing P127, disclosure pos1
# Processing P127, disclosure neu1
# Processing P127, disclosure neu2
# Processing P127, disclosure neg1
# Processing P127, disclosure neg2
# Processing P118, disclosure pos2
# Processing P118, disclosure pos1
# Processing P118, disclosure neu1
# Processing P118, disclosure neu2
# Processing P118, disclosure neg1
# Processing P118, disclosure neg2
# Processing P173, disclosure pos2
# Processing P173, disclosure pos1
# Processing P173, disclosure neu1
# Processing P173, disclosure neu2
# Processing P173, disclosure neg1
# Processing P173, disclosure neg2
# Processing P180, disclosure pos2
# Processing P180, disclosure pos1
# Processing P180, disclosure neu1
# Processing P180, disclosure neu2
# Processing P180, disclosure neg1
# Processing P180, disclosure neg2
# Processing P174, disclosure pos2
# Processing P174, disclosure pos1
# Processing P174, disclosure neu1
# Processing P174, disclosure neu2
# Processing P174, disclosure neg1
# Processing P174, disclosure neg2
# Processing P142, disclosure pos2
# Processing P142, disclosure pos1
# Processing P142, disclosure neu1
# Processing P142, disclosure neu2
# Processing P142, disclosure neg1
# Processing P142, disclosure neg2
# Processing P119, disclosure pos2
# Processing P119, disclosure pos1
# Processing P119, disclosure neu1
# Processing P119, disclosure neu2
# Processing P119, disclosure neg1
# Processing P119, disclosure neg2
# Processing P121, disclosure pos2
# Processing P121, disclosure pos1
# Processing P121, disclosure neu1
# Processing P121, disclosure neu2
# Processing P121, disclosure neg1
# Processing P121, disclosure neg2
# Processing P117, disclosure pos2
# Processing P117, disclosure pos1
# Processing P117, disclosure neu1
# Processing P117, disclosure neu2
# Processing P117, disclosure neg1
# Processing P117, disclosure neg2
# Processing P128, disclosure pos2
# Processing P128, disclosure pos1
# Processing P128, disclosure neu1
# Processing P128, disclosure neu2
# Processing P128, disclosure neg1
# Processing P128, disclosure neg2
# Processing P144, disclosure pos2
# Processing P144, disclosure pos1
# Processing P144, disclosure neu1
# Processing P144, disclosure neu2
# Processing P144, disclosure neg1
# Processing P144, disclosure neg2
# Processing P143, disclosure pos2
# Processing P143, disclosure pos1
# Processing P143, disclosure neu1
# Processing P143, disclosure neu2
# Processing P143, disclosure neg1
# Processing P143, disclosure neg2
# Processing P175, disclosure pos2
# Processing P175, disclosure pos1
# Processing P175, disclosure neu1
# Processing P175, disclosure neu2
# Processing P175, disclosure neg1
# Processing P175, disclosure neg2
# Processing P181, disclosure pos2
# Processing P181, disclosure pos1
# Processing P181, disclosure neu1
# Processing P181, disclosure neu2
# Processing P181, disclosure neg1
# Processing P181, disclosure neg2
# Processing P172, disclosure pos2
# Processing P172, disclosure pos1
# Processing P172, disclosure neu1
# Processing P172, disclosure neu2
# Processing P172, disclosure neg1
# Processing P172, disclosure neg2

# %%
# Concatenate into dataframe
all_acoustics_df = pd.concat(all_acoustics, ignore_index=True)
all_acoustics_df.head()
# Out:
#     ID disclosure  time       pitch  intensity      hf500    jitter   shimmer  \
# 0  136       pos2     0    0.000000  41.346587        NaN       NaN       NaN
# 1  136       pos2     1    0.000000  47.699112 -26.733634  0.047076  0.181635
# 2  136       pos2     2    0.000000  46.554955 -27.579789  0.051872  0.199222
# 3  136       pos2     3    0.000000  44.523244 -25.851204  0.040639  0.185166
# 4  136       pos2     4  131.660606  64.757791  -0.507906  0.026115  0.167235
#
#            f1           f2           f3           f4
# 0         NaN          NaN          NaN          NaN
# 1  141.985867  1610.922671  2430.555861  3312.397301
# 2  242.956539  1331.537117  2616.102797  4067.682468
# 3  214.696129  1465.180280  2407.977019  3344.571641
# 4  488.792226  2522.153741  3162.531435  4450.129528

# %%
# Save as csv
all_acoustics_df.to_csv('Data/processed/moment_to_moment/acoustic_features_by_window_1s.csv', index=False)

# %% [markdown]
# ### Test code for one individual recording

# %%
# Import audio recording
sound = parselmouth.Sound('Data/test.wav')

# %%
# Set parameters
f0min = 75 #75 for males, 100 for females
f0max = 500 # 300 for males, 500 for females
time_step = 1.0
tmin = math.floor(call(sound, "Get start time"))
tmax = math.ceil(call(sound, "Get end time"))

# %% [markdown]
# #### Compute pitch

# %%
pitch = sound.to_pitch(time_step, f0min, f0max)
pitch_values = pitch.selected_array['frequency']
len(pitch_values)
# Out:
# 190

# %% [markdown]
# #### Compute intensity

# %%
intensity = sound.to_intensity(f0min, time_step)
intensity_values = intensity.values[0]
len(intensity_values)
# Out:
# 190

# %% [markdown]
# #### Compute HF500

# %% [markdown]
# Code derived from praat implementation here: https://github.com/jjatria/plugin_prosodyad/blob/master/scripts/utterance_analysis.praat

# %%
hf500 = []
for time in range(tmin, tmax):
    sound_part = call(sound, "Extract part", time - time_step, time, "rectangular", 1, "yes")
    spectrum = call(sound_part, "To Spectrum", "yes")
    top = call(spectrum, "Get highest frequency")
    lo = call(spectrum, "Get band energy", 0, 500)
    hi = call(spectrum, "Get band energy", 500, top)
    # Convert sound pressure level from pascals to DB; set to nan if zero division occurs
    try:
        hf500_at_time = 10 * math.log10(hi / lo)
    except ZeroDivisionError:
        hf500_at_time = np.nan
    hf500.append(hf500_at_time)

# %% [markdown]
# #### Compute jitter (associated with rougher voices)

# %%
# local is most commonly used type of jitter
# looks like i'll have to use a for loop to get jitter over time...
# should check if this is kosher & what a good window size would be
# seems like betterup just used a one second window

jitter = []
for time in range(tmin, tmax):
    sound_part = call(sound, "Extract part", time - time_step, time, "rectangular", 1, "yes")
    pointProcess = call(sound_part, "To PointProcess (periodic, cc)", f0min, f0max)
    jitter_at_time = call(pointProcess, "Get jitter (local)", 0, 0, 0.0001, 0.02, 1.3)
    jitter.append(jitter_at_time)

#len(jitter)

# %% [markdown]
# #### Compute shimmer

# %%
shimmer = []
for time in range(tmin, tmax):
    sound_part = call(sound, "Extract part", time - time_step, time, "rectangular", 1, "yes")
    pointProcess = call(sound_part, "To PointProcess (periodic, cc)", f0min, f0max)
    shimmer_at_time = call([sound, pointProcess], "Get shimmer (local)", 0, 0, 0.0001, 0.02, 1.3, 1.6)
    shimmer.append(shimmer_at_time)

#len(shimmer)

# %% [markdown]
# #### Compute formants

# %%
formants = call(sound, "To Formant (burg)", 0.0025, 5, 5000, 0.025, 50)

f1_list = []
f2_list = []
f3_list = []
f4_list = []

for time in range(tmin, tmax):
    f1 = call(formants, "Get value at time", 1, time, 'Hertz', 'Linear')
    f2 = call(formants, "Get value at time", 2, time, 'Hertz', 'Linear')
    f3 = call(formants, "Get value at time", 3, time, 'Hertz', 'Linear')
    f4 = call(formants, "Get value at time", 4, time, 'Hertz', 'Linear')
    f1_list.append(f1)
    f2_list.append(f2)
    f3_list.append(f3)
    f4_list.append(f4)

# %% [markdown]
# #### Save to data file

# %%
times = list(range(tmin, tmax))
ID='01'

# %%
df = pd.DataFrame({
    'ID': ID,
    'time': times, 
    'pitch': pitch_values, 
    'intensity': intensity_values,
    'jitter': jitter,
    'shimmer': shimmer,
    'f1': f1_list,
    'f2': f2_list,
    'f3': f3_list,
    'f4': f4_list
    })

# %%
df.to_csv('Data/accoustics.csv', index=False)

# %% [markdown]
# ### Play with parallel code

# %%
import multiprocessing
from joblib import Parallel, delayed
from tqdm import tqdm

# %%
num_cores = multiprocessing.cpu_count()
recordings = [file for file in files for subdir, dirs, files in os.walk('Data/recordings') 
          if '/P' in os.path.join(subdir, file) and 'self' in os.path.join(subdir, file)]
inputs = tqdm(recordings)

# %%
def get_accoustic_features

# %%
if __name__ == "__main__":
    processed_list = Parallel(n_jobs=num_cores)(delayed(myfunction)(i,parameters) for i in inputs)
